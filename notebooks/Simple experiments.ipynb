# %%
from tclab import runexperiment

# %%
# %matplotlib notebook

# %%
def onoffcontroller(t, lab):
    lab.Q1(0 if t < 5 else 100)

# %%
experiment = runexperiment(onoffcontroller, connected=False, time=100, speedup=10)
# Out:
# Simulated TCLab
# <img src="data:image/png;base64,..." width="800">
# TCLab Model disconnected successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-99e95fc21a95> in <module>()
# ----> 1 experiment = runexperiment(onoffcontroller, connected=False, time=100, speedup=10)
#
# ~/Documents/Development/TCLab/tclab/experiment.py in runexperiment(function, connected, plot, twindow, time, speedup)
#      47                   speedup=1):
#      48     with Experiment(connected, plot, twindow, time) as experiment:
# ---> 49         for t in experiment.clock():
#      50             function(t, experiment.lab)
#      51     return experiment
#
# ~/Documents/Development/TCLab/tclab/experiment.py in clock(self)
#      35
#      36     def clock(self):
# ---> 37         for t in clock(self.time):
#      38             if self.plot:
#      39                 self.plotter.update(t)
#
# ~/Documents/Development/TCLab/tclab/clock.py in clock(tperiod, tstep, tol)
#      47             gc.disable()
#      48             try:
# ---> 49                 realtime.sleep(max(0, tsleep/SPEEDUP))
#      50             finally:
#      51                 if gcold:
#
# KeyboardInterrupt:

# %%
experiment.historian.log
# Out:
# [(0, 21.110368382170215, 21.217202209413962, 0, 0),
#  (0, 20.944882594899255, 20.830100479581194, 0, 0),
#  (1.0, 20.973841946188273, 21.004901147261688, 0, 0),
#  (2.0, 20.79488141599042, 21.489615371784186, 0, 0),
#  (3.0, 20.98525352537859, 20.98155053749184, 0, 0),
#  (4.0, 21.260782413481664, 20.78877694832336, 0, 0),
#  (5.0, 21.03434424484723, 21.267081059321765, 0, 0),
#  (6.0, 21.409331479818118, 21.00999157569085, 100, 0),
#  (7.0, 21.019567173718393, 21.130706918349954, 100, 0),
#  (8.0, 21.17013685634511, 21.007381857989568, 100, 0),
#  (9.0, 21.448197321122436, 20.852780247423112, 100, 0),
#  (10.0, 21.270589249541917, 21.11248015706409, 100, 0)]
