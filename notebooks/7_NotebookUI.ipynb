# %% [markdown]
# # NotebookUI
#
# The `tclab.gui` module supplies a graphical interface to the Temperature Control Laboratory.

# %%
from tclab.gui import NotebookUI

# %%
# %matplotlib notebook

# %%
interface = NotebookUI()

# %%
interface.gui
# Out:
# A Jupyter Widget
# Simulated TCLab
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Accessing past sessions
#
# Once you have finished the experiment, you can see what sessions the historian stored as follows:

# %%
interface.historian.get_sessions()
# Out:
# [(1, '2018-02-11 14:57:08')]

# %% [markdown]
# The historian can load data from one of the previous sessions. Note that this will overwrite the data currently stored in the historian.

# %%
interface.historian.load_session(1)

# %% [markdown]
# Once the data have been loaded, the historian will support all the same commands as if only one session was used.

# %%
interface.historian.log
# Out:
# [(1, 21.28947767113773, 20.879690733503676, 0, 0),
#  (2, 21.021076031179685, 21.413337015889542, 39.8, 0),
#  (3, 21.07058748269809, 21.19430083977317, 39.8, 0),
#  (4, 21.245664114387314, 20.755307590156185, 39.8, 48.7),
#  (5, 20.810461601460485, 20.77070916696551, 39.8, 51.1),
#  (6, 21.36772446900633, 21.499888666493682, 39.8, 51.1),
#  (7, 20.959480495169814, 21.277963278591333, 39.8, 51.1),
#  (8, 21.13955738687507, 21.450561214961915, 39.8, 51.1),
#  (9, 21.115603792205558, 21.656314599920215, 39.8, 51.1),
#  (10, 21.631855078825883, 21.26970787819244, 39.8, 51.1)]
